# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\shaik\Downloads\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.1.3

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.3

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.describe().transpose()
# Out:
#                 count         mean        std     min     25%     50%     75%  \
# CriticRating    559.0    47.309481  26.413091     0.0    25.0    46.0    70.0
# AudienceRating  559.0    58.744186  16.826887     0.0    47.0    58.0    72.0
# BudgetMillions  559.0    50.236136  48.731817     0.0    20.0    35.0    65.0
# Year            559.0  2009.152057   1.362632  2007.0  2008.0  2009.0  2010.0
#
#                    max
# CriticRating      97.0
# AudienceRating    96.0
# BudgetMillions   300.0
# Year            2011.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', kind='hex')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', kind='scatter')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', kind='reg')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', kind='kde')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', kind='hist')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', kind='resid')

# %%
p1 = sns.distplot(movies.AudienceRating)

# %%
sns.set_style('darkgrid')

# %%
p2 = sns.distplot(movies.AudienceRating,bins=15)

# %%
r1= plt.hist(movies.AudienceRating,bins=15)

# %%
sns.set_style('white')
r1=plt.hist(movies.AudienceRating,bins=20)

# %%
r2=plt.hist(movies.CriticRating,bins=20)

# %%
sns.histplot(movies.BudgetMillions)
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='Count'>

# %%
plt.hist(movies['BudgetMillions'])
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',fit_reg= False)

# %%
vis2= sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating',hue = 'Genre',fit_reg = True)

# %%
vis3= sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating',hue = 'Genre',fit_reg = False)

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre=='Thrilling'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,bins=20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
          movies[movies.Genre=='Drama'].BudgetMillions,\
          movies[movies.Genre=='Thrilling'].BudgetMillions,\
          movies[movies.Genre=='Comedy'].BudgetMillions],
         bins=20, stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
h1 = sns.kdeplot(
    x= movies['CriticRating'],
    y= movies['AudienceRating'],
    shade = True, shade_lowest = False,
    cmap = 'Reds'
)

# %%
h2 = sns.kdeplot(
    x= movies['CriticRating'],
    y= movies['AudienceRating'],
    shade_lowest = False,
    cmap = 'Greens_r'
)

# %%
sns.set_style('dark')
h3 = sns.kdeplot(
    x= movies['BudgetMillions'],
    y= movies['AudienceRating'],
    cmap = 'nipy_spectral',
    shade_lowest = False
)

# %%
h4= sns.kdeplot(
    x = movies.BudgetMillions,
    y = movies.AudienceRating,
    cmap = 'twilight_shifted'
)

# %%
h5 = sns.kdeplot(
    x = movies['BudgetMillions'],
    y = movies['CriticRating'],
    cmap = 'viridis'
)

# %% [markdown]
# ### Subplots

# %%
f, ax = plt.subplots(1,2, figsize = (12,6))

# %%
f, axes = plt.subplots(1,2, figsize = (12,6))

h1 = sns.kdeplot(
    x = movies['BudgetMillions'],
    y = movies['AudienceRating'],
    ax = axes[0], cmap = 'seismic'
)
h2  = sns.kdeplot(
    x = movies['BudgetMillions'],
    y = movies['CriticRating'],
    ax= axes[1],
    cmap = 'magma'
)

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
# boxplot
v = sns.boxplot(data = movies, x = 'Genre',y = 'CriticRating')

# %%
w = sns.violinplot(data = movies, x = 'Genre', y = 'CriticRating',palette ='tab10')

# %%
t1 = sns.boxplot(
    data = movies[movies.Genre == 'Drama'],
    x = 'Year', y = 'CriticRating',
    palette = 'viridis'
)

# %%
p = sns.violinplot(
    data = movies[movies['Genre'] == 'Drama'],
    x = 'Year', y = 'CriticRating', palette = 'magma'
)

# %% [markdown]
# ### Creating a Facet Grid

# %%
facet = sns.FacetGrid(data=movies, row = 'Genre',
                     col = 'Year', hue = 'Genre')

# %%
plt.scatter(movies.CriticRating, movies.AudienceRating)

# %%
facet = sns.FacetGrid(movies, row = 'Genre',
                     col = 'Year', hue = 'Genre')
values = facet.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
f = sns.FacetGrid(movies, row = 'Genre',
                 col = 'Year', hue = 'Genre')
values1= f.map(plt.hist, 'BudgetMillions')

# %%
f = sns.FacetGrid(movies, row = 'Genre',
                 col = 'Year', hue = 'Genre')
k = dict(s = 50, linewidth = 0.5, edgecolor = 'black')
d = f.map(plt.scatter, 'CriticRating', 'AudienceRating', **k)
